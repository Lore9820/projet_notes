# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
logs = pd.read_csv("projet_notes/logs.csv", parse_dates=['heure'])
notes = pd.read_csv("projet_notes/notes.csv")

# %% [markdown]
# # LOGS

# %%
logs.head()
# Out:
#                 heure  pseudo                               contexte  \
# 0 2023-12-15 11:04:49     744  Cours: L3 MIAGE : Compilation (23-24)
# 1 2023-12-15 13:44:53     744  Cours: L3 MIAGE : Compilation (23-24)
# 2 2023-12-15 17:01:29     744  Cours: L3 MIAGE : Compilation (23-24)
# 3 2023-12-20 09:02:55     744  Cours: L3 MIAGE : Compilation (23-24)
# 4 2023-12-20 09:26:59     744  Cours: L3 MIAGE : Compilation (23-24)
#
#   composant                  evenement
# 0   Système  Sauvegarde de cours créée
# 1   Système  Sauvegarde de cours créée
# 2   Système  Sauvegarde de cours créée
# 3   Système  Sauvegarde de cours créée
# 4   Système  Sauvegarde de cours créée

# %%
notes.head()
# Out:
#    pseudo note
# 0     257    8
# 1     573    3
# 2     585   11
# 3     626    9
# 4      66    9

# %%
print("logs :", logs.shape)
print("notes :", notes.shape)
# Out:
# logs : (29006, 5)
# notes : (80, 2)

# %%
print('\nNull Values \n{}'.format(logs.isnull().sum()))
# Out:
# Null Values
# heure        0
# pseudo       0
# contexte     0
# composant    0
# evenement    0
# dtype: int64

# %%
print('\nNull Values \n{}'.format(notes.isnull().sum()))
# Out:
# Null Values
# pseudo    0
# note      0
# dtype: int64

# %%
logs.describe(include="all").T
# Out:
#                     count unique                              top   freq  \
# heure               27771    NaN                              NaN    NaN
# pseudo            27771.0    NaN                              NaN    NaN
# composant           27771     13                          Système  11134
# evenement           27771     27         Module de cours consulté   9484
# contexte_general    27771      8                          Fichier  10201
# specification       27771     45   L3 MIAGE : Compilation (23-24)   7347
# jour                27771    NaN                              NaN    NaN
# heures              27771  15593                         16:16:56     13
#
#                                            mean                  min  \
# heure             2024-02-23 16:27:58.541896192  2024-01-07 13:41:39
# pseudo                               455.805877                  5.0
# composant                                   NaN                  NaN
# ...

# %%
notes.describe(include="all").T
# Out:
#        count unique  top freq      mean         std  min    25%    50%  \
# pseudo  80.0    NaN  NaN  NaN  457.9375  271.364734  5.0  221.0  461.5
# note      80     19    2    9       NaN         NaN  NaN    NaN    NaN
#
#            75%     max
# pseudo  669.25  1000.0
# note       NaN     NaN

# %%
logs
# Out:
#                     heure  pseudo                               contexte  \
# 0     2023-12-15 11:04:49     744  Cours: L3 MIAGE : Compilation (23-24)
# 1     2023-12-15 13:44:53     744  Cours: L3 MIAGE : Compilation (23-24)
# 2     2023-12-15 17:01:29     744  Cours: L3 MIAGE : Compilation (23-24)
# 3     2023-12-20 09:02:55     744  Cours: L3 MIAGE : Compilation (23-24)
# 4     2023-12-20 09:26:59     744  Cours: L3 MIAGE : Compilation (23-24)
# ...                   ...     ...                                    ...
# 29001 2024-12-14 09:49:44     425  Cours: L3 MIAGE : Compilation (23-24)
# 29002 2024-12-14 09:51:04     425  Cours: L3 MIAGE : Compilation (23-24)
# 29003 2024-12-14 09:52:50     425           Questionnaire: Questionnaire
# 29004 2024-12-14 10:04:56     425  Cours: L3 MIAGE : Compilation (23-24)
# 29005 2024-12-14 10:08:07     425  Cours: L3 MIAGE : Compilation (23-24)
#
#            composant                  evenement
# ...

# %%
logs.groupby('composant').size().reset_index(name='count')
# Out:
#                   composant  count
# 0       Affichage simplifié     23
# 1   Bloc-notes collaboratif    416
# 2              Commentaires      3
# 3                    Devoir   4139
# 4   Feuille de calcul Excel      1
# 5                   Fichier   6537
# 6                     Forum    274
# 7                  Journaux      1
# 8                  Présence   4279
# 9             Questionnaire    558
# 10  Rapport de l’évaluateur     24
# 11   Rapport du participant    207
# 12       Rapport d’ensemble      7
# 13      Remises de fichiers    376
# 14                  Système  12067
# 15          Visites guidées      6
# 16                  Wooclap     88

# %%
logs.groupby('evenement').size().reset_index(name='count')
# Out:
#                            evenement  count
# 0                    Abonnement créé     81
# 1      Achèvement d’activité modifié   4023
# 2                 Capacité attribuée      1
# 3    Catégorie de question consultée      1
# 4                   Commentaire créé      3
# ..                               ...    ...
# 56         Élément d’évaluation créé     13
# 57      Élément d’évaluation modifié     29
# 58      Événement de calendrier créé     42
# 59   Événement de calendrier modifié     17
# 60  Événement de calendrier supprimé      2
#
# [61 rows x 2 columns]

# %%
logs.groupby('contexte').size().reset_index(name='count')
# Out:
#                                              contexte  count
# 0   Bloc-notes collaboratif: Composition de votre ...    418
# 1               Cours: L3 MIAGE : Compilation (23-24)   8254
# 2   Devoir: Espace de dépôt : Exercice #4 (Assembl...    471
# 3   Devoir: Espace de dépôt de l'activité "Cahier ...    773
# 4   Devoir: Espace de dépôt de l'exercice de prise...    765
# 5            Devoir: Espace de dépôt de l'étape #2...    608
# 6   Devoir: Espace de dépôt du rapport de l'étape ...    818
# 7   Devoir: dépôt Exercice#4 assembleur (condition...   1332
# 8                           Fichier: Analyse lexicale    331
# 9               Fichier: Analyse syntaxique (Parsing)    238
# 10                           Fichier: Assembleur BETA    611
# 11                                       Fichier: CUP    401
# 12                   Fichier: CUP + Java : Expression    309
# 13             Fichier: Code xml à ajouter au pom.xml    334
# ...

# %%
logs = logs[logs["pseudo"].isin(notes["pseudo"])]
logs.head()
# Out:
#                   heure  pseudo                      contexte      composant  \
# 335 2024-01-07 13:41:39     525  Questionnaire: Questionnaire  Questionnaire
# 336 2024-01-07 13:41:53     525  Questionnaire: Questionnaire  Questionnaire
# 356 2024-01-07 20:48:57     311  Questionnaire: Questionnaire  Questionnaire
# 357 2024-01-07 20:49:04     311  Questionnaire: Questionnaire  Questionnaire
# 358 2024-01-07 20:49:17     311  Questionnaire: Questionnaire  Questionnaire
#
#                     evenement
# 335  Module de cours consulté
# 336  Module de cours consulté
# 356  Module de cours consulté
# 357  Module de cours consulté
# 358  Module de cours consulté

# %%
logs.shape
# Out:
# (27771, 5)

# %%
logs[["contexte_general", "specification"]] = logs["contexte"].str.split(":", n=1, expand=True)
logs.head()
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_15148\827243699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   logs[["contexte_general", "specification"]] = logs["contexte"].str.split(":", n=1, expand=True)
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_15148\827243699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   logs[["contexte_general", "specification"]] = logs["contexte"].str.split(":", n=1, expand=True)
# ...

# %%
logs.shape
# Out:
# (27771, 7)

# %%
logs = logs.drop(["contexte"], axis=1)
logs.head()
# Out:
#                   heure  pseudo      composant                 evenement  \
# 335 2024-01-07 13:41:39     525  Questionnaire  Module de cours consulté
# 336 2024-01-07 13:41:53     525  Questionnaire  Module de cours consulté
# 356 2024-01-07 20:48:57     311  Questionnaire  Module de cours consulté
# 357 2024-01-07 20:49:04     311  Questionnaire  Module de cours consulté
# 358 2024-01-07 20:49:17     311  Questionnaire  Module de cours consulté
#
#     contexte_general   specification
# 335    Questionnaire   Questionnaire
# 336    Questionnaire   Questionnaire
# 356    Questionnaire   Questionnaire
# 357    Questionnaire   Questionnaire
# 358    Questionnaire   Questionnaire

# %%
logs.shape
# Out:
# (27771, 6)

# %%
logs["jour"] = logs["heure"].dt.date
logs["heures"] = logs["heure"].dt.time
logs.head()
# Out:
#                   heure  pseudo      composant                 evenement  \
# 335 2024-01-07 13:41:39     525  Questionnaire  Module de cours consulté
# 336 2024-01-07 13:41:53     525  Questionnaire  Module de cours consulté
# 356 2024-01-07 20:48:57     311  Questionnaire  Module de cours consulté
# 357 2024-01-07 20:49:04     311  Questionnaire  Module de cours consulté
# 358 2024-01-07 20:49:17     311  Questionnaire  Module de cours consulté
#
#     contexte_general   specification        jour    heures
# 335    Questionnaire   Questionnaire  2024-01-07  13:41:39
# 336    Questionnaire   Questionnaire  2024-01-07  13:41:53
# 356    Questionnaire   Questionnaire  2024-01-07  20:48:57
# 357    Questionnaire   Questionnaire  2024-01-07  20:49:04
# 358    Questionnaire   Questionnaire  2024-01-07  20:49:17

# %%
logs.shape
# Out:
# (27771, 8)

# %%
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27771 entries, 335 to 28993
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   heure             27771 non-null  datetime64[ns]
#  1   pseudo            27771 non-null  int64
#  2   composant         27771 non-null  object
#  3   evenement         27771 non-null  object
#  4   contexte_general  27771 non-null  object
#  5   specification     27771 non-null  object
#  6   jour              27771 non-null  object
#  7   heures            27771 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 1.9+ MB

# %%
logs["jour"] = pd.to_datetime(logs["jour"])
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27771 entries, 335 to 28993
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   heure             27771 non-null  datetime64[ns]
#  1   pseudo            27771 non-null  int64
#  2   composant         27771 non-null  object
#  3   evenement         27771 non-null  object
#  4   contexte_general  27771 non-null  object
#  5   specification     27771 non-null  object
#  6   jour              27771 non-null  datetime64[ns]
#  7   heures            27771 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(5)
# memory usage: 1.9+ MB

# %%
logs.groupby('contexte_general').size().reset_index(name='count')
# Out:
#           contexte_general  count
# 0  Bloc-notes collaboratif    389
# 1                    Cours   7347
# 2                   Devoir   4707
# 3                  Fichier  10201
# 4                    Forum    171
# 5                 Présence   4231
# 6            Questionnaire    640
# 7                  Wooclap     85

# %%
logs.groupby('specification').size().reset_index(name='count')
# Out:
#                                         specification  count
# 0                                    Analyse lexicale    330
# 1                        Analyse syntaxique (Parsing)    237
# 2                                     Assembleur BETA    607
# 3                                                 CUP    397
# 4                             CUP + Java : Expression    305
# 5                       Code xml à ajouter au pom.xml    330
# 6        Code à ajouter dans pom.xml pour Cup & JFLex    234
# 7                  Composition de votre équipe projet    389
# 8    Correction : Analyseur syntaxique d'une expre...    122
# 9    Correction : Evaluation d'une expression de c...    119
# 10      Correction TD Arbre et Génération Expressioon    287
# 11                Correction de l'exercice Word Count    104
# 12                               Ecrire une grammaire    215
# 13                                     Equipes Projet    260
# ...

# %%
logs.groupby('evenement').size().reset_index(name='count')
# Out:
#                                            evenement  count
# 0                      Achèvement d’activité modifié   4006
# 1                                   Commentaire créé      3
# 2   Confirmation de suppression de travail consultée     11
# 3                                     Cours consulté   6921
# 4                               Discussion consultée    106
# 5                                     Fichier déposé    188
# 6                      Formulaire de remise consulté    233
# 7                     Liste d’utilisateurs consultée     68
# 8                           Module de cours consulté   9484
# 9                        Profil utilisateur consulté     15
# 10                           Questionnaire poursuivi      1
# 11                              Questionnaire soumis    100
# 12             Rapport de cours utilisateur consulté     36
# 13                       Rapport de session consulté   3039
# 14       Rapport des réponses individuelles consulté     69
# ...

# %% [markdown]
# # NOTES

# %%
notes.head()
# Out:
#    pseudo note
# 0     257    8
# 1     573    3
# 2     585   11
# 3     626    9
# 4      66    9

# %%
notes.describe(include='all')
# Out:
#              pseudo note
# count     80.000000   80
# unique          NaN   19
# top             NaN    2
# freq            NaN    9
# mean     457.937500  NaN
# std      271.364734  NaN
# min        5.000000  NaN
# 25%      221.000000  NaN
# 50%      461.500000  NaN
# 75%      669.250000  NaN
# max     1000.000000  NaN

# %%
notes.shape
# Out:
# (80, 2)
